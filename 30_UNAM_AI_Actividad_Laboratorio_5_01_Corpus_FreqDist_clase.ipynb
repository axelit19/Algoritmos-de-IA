# %% [markdown]
# <a href="https://colab.research.google.com/github/axelit19/Algoritmos-de-IA/blob/main/30_UNAM_AI_Actividad_Laboratorio_5_01_Corpus_FreqDist_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# $\Huge \textbf{Universidad Nacional Autónoma de México}$
# $\Huge \textbf{Facultad de Ciencias}$
# <p align="center">
#   <img src="https://www.icat.unam.mx/wp-content/uploads/2021/11/Copia-de-LogoUNAM.-Azul.-Fondo-transparente.png" alt="UNAM" width="200"/>
# </p>
#
# <hr style="height:3px; background-color:#0B6E4F; border:none;"/>
#
#
# $\LARGE \textbf{Inteligencia Artificial}$
#
# $\Large \textit{Laboratorio 2.3}$
#
#
# \begin{array}{rl}
# \textbf{Docente:} & Dra. Jessica Sarahi Méndez Rincón \\[6pt]
# \textbf{Ayudante de laboratorio:} & Diego Eduardo Peña Villegas \\[6pt]
# \textbf{Alumna:} & Axel Alejandro Godinez Hernandez \\[6pt]
# \textbf{Fecha de realización:} & 06/05/2026
# \end{array}
#
# </center>

# %% [markdown]
# # Instalación de Paquetes

# %% [markdown]
# Una vez se instale la librería NLTK, es posible acceder fácilmente a recursos léxicos y comenzar con el procesamiento de textos. NLTK incluye una pequeña selección de textos del Proyecto Gutenberg, que contiene unos 60,000 libros electrónicos gratuitos.

# %%
pip install NLTK
# Out:
# Requirement already satisfied: NLTK in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from NLTK) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from NLTK) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from NLTK) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from NLTK) (4.67.1)

# %% [markdown]
# # Librerías que usaremos

# %% [markdown]
# Para acceder a este corpus, se debe cargar la librería NLTK previamente instalada y descargar el corpus del Proyecto Gutenberg. Adicional a ello, es posible enlistar los archivos incluidos en el corpus.

# %%
import nltk
from nltk.corpus import gutenberg
from nltk.corpus import stopwords

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# Al utilizar la función words() del objeto gutenberg en el paquete corpus del NLTK, se podrá tener acceso al recurso que se desee, por ejemplo “La tragedia de Hamlet, príncipe de Dinamarca” de William Shakespeare y así, obtener información estadística sobre el texto.

# %%
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')

# %%
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %% [markdown]
# Se puede observar la cantidad de caracteres, palabras y oraciones del texto, así como la longitud promedio de una palabra, de una oración y la cantidad de veces que cada elemento del vocabulario aparece en el texto en promedio, es decir, la diversidad léxica del texto. Es importante notar que con estos estadísticos se obtiene información sobre características del idioma (longitud de la palabra) o características particulares del autor (longitud de oración promedio y diversidad léxica).

# %%
#Descarga el corpus punkt que me sirve para aplicar la funcipin raw
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# El uso de la función **raw()** permite acceder al texto tal cual, sin algún tipo de procesamiento lingüístico. Por ejemplo, **len(gutenberg.raw('shakespeare-hamlet.txt'))** devuelve la cantidad de letras en el texto, incluyendo los espacios en blanco entre las palabras.
#
# La función **sents()** separa al texto en oraciones que se construyen a partir de una lista de palabras.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
num_caracteres = len(gutenberg.raw('shakespeare-hamlet.txt'))
num_palabras = len(gutenberg.words('shakespeare-hamlet.txt'))
num_oraciones = len(gutenberg.sents('shakespeare-hamlet.txt'))
num_vocab = len(set([w.lower() for w in gutenberg.words('shakespeare-hamlet.txt')]))

print('Cantidad de caracteres: ',num_caracteres )
print('Cantidad de palabras: ',num_palabras )
print('Cantidad de oraciones: ',num_oraciones )
print('Longitud promedio de una palabra: ',int(num_caracteres/num_palabras) )
print('Longitud promedio de una oracion: ',int(num_palabras/num_oraciones) )
print('Diversidad léxica: ',int(num_palabras/num_vocab) )
# Out:
# Cantidad de caracteres:  162881
# Cantidad de palabras:  37360
# Cantidad de oraciones:  3106
# Longitud promedio de una palabra:  4
# Longitud promedio de una oracion:  12
# Diversidad léxica:  7

# %% [markdown]
# El Corpus Brown fue el primer corpus electrónico de un millón de palabras en inglés, creado en 1961 en la Universidad de Brown. Contiene textos de 500 fuentes y las fuentes se han categorizado por género, como noticias, editoriales, etc.

# %%
oraciones_macbeth = gutenberg.sents('shakespeare-hamlet.txt')
oraciones_macbeth[1037]
# Out:
# ['the',
#  'beauty',
#  'of',
#  'the',
#  'world',
#  ',',
#  'the',
#  'Parragon',
#  'of',
#  'Animals',
#  ';',
#  'and',
#  'yet',
#  'to',
#  'me',
#  ',',
#  'what',
#  'is',
#  'this',
#  'Quintessence',
#  'of',
#  'Dust',
#  '?']

# %% [markdown]
# Es posible acceder al corpus ya sea como una lista de palabras o una lista de oraciones (donde cada oración es, en sí misma, una lista de palabras). Opcionalmente, se puede especificar categorías o archivos particulares para leer.

# %%
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# Esta pantalla se obtuvo directamente del software que se está explicando en la computadora, para fines educativos.
#
# El Corpus Brown es un recurso útil para estudiar las diferencias sistemáticas entre géneros, conocida como estilística o estudio del estilo. A continuación puedes notar la diferencia en el uso de los verbos modales en textos de noticias y de romance.

# %%
noticias = brown.words(categories='religion')
distribucion_frecuencias = nltk.FreqDist([w.lower() for w in noticias])
verbo_modal = ['can','could','may','migth','must','will']
for m in verbo_modal:
  print(m + ":", distribucion_frecuencias[m],)
# Out:
# can: 84
# could: 59
# may: 79
# migth: 0
# must: 54
# will: 72

# %%
noticias = brown.words(categories='romance')
dist_frec = nltk.FreqDist([w.lower() for w in noticias])
verbo_modal = ['can','could','may','migth','must','will']
for m in verbo_modal:
  print(m + ":", dist_frec[m],)
# Out:
# can: 79
# could: 195
# may: 11
# migth: 0
# must: 46
# will: 49

# %% [markdown]
# Los verbos modales son verbos auxiliares que expresan una opinión sobre si algo es posible o probable, también son utilizados para pedir permiso o hacer algún tipo de petición o hablar de habildiad, orden, obligación o consejo.
#
# En los resultados anteriores se observa que el verbo modal más utilizado en textos de noticias es will y en textos de romance es could y este tipo de información puede ser utilizada para establecer distinciones entre géneros en un texto escrito.

# %% [markdown]
# # Procesamiento de texto puro

# %% [markdown]
# En está sección se identificará que hace que un texto sea distinto, utilizando métodos automáticos para encontrar palabras y expresiones características de un texto.
#
# Una forma de identificar cuáles son las palabras que proporcionan más información sobre un texto es contando las veces que la palabra se utiliza dentro del texto.
#
# La distribución de frecuencias, indica la periodicidad de cada elemento de un vocabulario en un texto. El término distribución indica como se reparte el número total de palabras en el texto.
#
# A continuación se pueden observar las 20 palabras más frecuentes en la novela "Emma" de Jane Austen y también un fragmento de aquellas palabras que solo aparecen una sola vez, conocidas como hapax o hápax legómenon.

# %%
palabras = gutenberg.words('austen-emma.txt')
dist_frec = nltk.FreqDist([w.lower() for w in palabras])
dist_frec.most_common(20)
# Out:
# [(',', 11454),
#  ('.', 6928),
#  ('to', 5239),
#  ('the', 5201),
#  ('and', 4896),
#  ('of', 4291),
#  ('i', 3178),
#  ('a', 3129),
#  ('it', 2528),
#  ('her', 2469),
#  ('was', 2398),
#  ('she', 2340),
#  (';', 2199),
#  ('in', 2188),
#  ('not', 2140),
#  ('"', 2004),
#  ('you', 1980),
#  ('be', 1975),
#  ('that', 1806),
#  ('he', 1806)]

# %%
dist_frec.hapaxes()
# Out:
# ['austen',
#  '1816',
#  ']',
#  'vex',
#  'indistinct',
#  'caresses',
#  'nominal',
#  'mildness',
#  'impose',
#  'esteeming',
#  'disadvantages',
#  'misfortunes',
#  'mournful',
#  'debt',
#  'tenderer',
#  'valetudinarian',
#  'amounting',
#  'equals',
#  'lieu',
#  'awoke',
#  'chatted',
#  'housemaid',
#  'curtseys',
#  'needlework',
#  'lock',
#  'bangs',
#  'speck',
#  'rained',
#  'gainer',
#  'punctual',
#  'deathbed',
#  'broadway',
#  'drizzle',
#  'mitchell',
#  ',\'"',
#  'supposes',
#  'delicately',
#  'encouragements',
#  'grievously',
#  'fitted',
#  'homely',
#  'embodied',
#  'military',
#  'dissuaded',
#  'pursue',
#  'luxuries',
#  'poorer',
#  'lingering',
#  'kindred',
#  'competence',
#  'portionless',
#  'tyrannic',
#  'choose',
#  'avowed',
#  'adoption',
#  'assume',
#  'capricious',
#  'boasts',
#  'dissentient',
#  'prized',
#  'ennui',
#  'companionableness',
#  'feeble',
#  'hindrance',
#  'ceasing',
#  'teased',
#  'apothecary',
#  'bias',
#  'newly',
#  'unfrequently',
#  'exchanging',
#  'quadrille',
#  'untoward',
#  'predicament',
#  'frighten',
#  'cleverness',
#  'universal',
#  'quicksighted',
#  'gossip',
#  'seminary',
#  'combine',
#  'morality',
#  'systems',
#  'enormous',
#  'screwed',
#  'boarding',
#  'accomplishments',
#  'prodigies',
#  'repute',
#  'chilblains',
#  'win',
#  'sixpences',
#  'remedy',
#  'prosings',
#  'requesting',
#  'mansion',
#  'scholar',
#  'plump',
#  'inconveniently',
#  'shy',
#  'artlessly',
#  'wasted',
#  'renting',
#  'creditably',
#  'unpolished',
#  'detach',
#  'betweens',
#  'impulse',
#  'honours',
#  'minced',
#  'scalloped',
#  'oysters',
#  'cloth',
#  'constrain',
#  'nicer',
#  'boiling',
#  'tarts',
#  'preserves',
#  'custard',
#  '_half_',
#  '_small_',
#  'tumbler',
#  'personage',
#  'affability',
#  'privileges',
#  'docile',
#  'appreciating',
#  'usefulness',
#  'talkativeness',
#  '_two_',
#  'cows',
#  'alderneys',
#  'narrative',
#  'forever',
#  'inspiriting',
#  'games',
#  'shepherd',
#  'flock',
#  'wool',
#  '_wanted_',
#  'prince',
#  'richardson',
#  'sup',
#  'agricultural',
#  'wakefield',
#  'yeomanry',
#  'creditable',
#  '8th',
#  'birthday',
#  '23rd',
#  'afloat',
#  'diligence',
#  'indoors',
#  'fluctuations',
#  'respectfully',
#  'unfeigned',
#  'survey',
#  'contrasted',
#  'noticed',
#  'uncouthness',
#  'unmodulated',
#  '_gentleman_',
#  'loudness',
#  'coarseness',
#  'detestable',
#  'solemnly',
#  'gross',
#  'inattentive',
#  'engrosses',
#  'market',
#  'thriving',
#  'thrive',
#  'bluntness',
#  'commanding',
#  'copying',
#  'sufferable',
#  'ingratiating',
#  'efficacy',
#  'fastidious',
#  'riding',
#  'quarrels',
#  'fight',
#  'battle',
#  'neatly',
#  'alphabetically',
#  'industry',
#  'stimulate',
#  'affirm',
#  'omitting',
#  'cleverest',
#  'cope',
#  'inherits',
#  'wantonness',
#  'possibilities',
#  'foretelling',
#  'undesigned',
#  'hourly',
#  'doctrines',
#  'tend',
#  'polish',
#  'personally',
#  'errs',
#  'spleen',
#  'unkind',
#  'hinting',
#  'accountable',
#  'approves',
#  'province',
#  'outcry',
#  'gently',
#  'attractions',
#  'artlessness',
#  'superadded',
#  'skilful',
#  'seconded',
#  'landscapes',
#  'flowers',
#  'pieces',
#  'peculiarity',
#  'portfolio',
#  'portraits',
#  'beginnings',
#  'miniatures',
#  'crayon',
#  'reputation',
#  'ecstasies',
#  'performances',
#  'stealth',
#  'sheet',
#  'coarser',
#  'featured',
#  'fourth',
#  'cockade',
#  'nestled',
#  'unclosing',
#  'pet',
#  'vowed',
#  'apologised',
#  'forswear',
#  '_present_',
#  'portrait',
#  'fidgeting',
#  'stationing',
#  'irksomeness',
#  'intermission',
#  'charmed',
#  'encourager',
#  'filling',
#  'memorial',
#  'associations',
#  'permission',
#  'courtesies',
#  'defended',
#  'criticism',
#  'eyelashes',
#  'fore',
#  'shortening',
#  'doer',
#  'commissions',
#  'stirring',
#  'fogs',
#  'executing',
#  'pack',
#  'incommoding',
#  'mostly',
#  'deposit',
#  'languish',
#  'services',
#  'songs',
#  'copy',
#  'grammatical',
#  'composition',
#  'diffuse',
#  'pen',
#  'vigorous',
#  'unequivocal',
#  'demurs',
#  'inflicting',
#  'unbidden',
#  'misunderstanding',
#  '_purport_',
#  'wording',
#  'contemplating',
#  '_doubts_',
#  'thoughtfully',
#  'mechanically',
#  'twisted',
#  'aghast',
#  'offending',
#  'formation',
#  'brace',
#  'sealed',
#  'tittle',
#  'tattle',
#  'softly',
#  'mounts',
#  'opens',
#  'introduces',
#  'diffuses',
#  'prepossession',
#  'slept',
#  'invalids',
#  'substitute',
#  'walker',
#  'tedious',
#  'greatcoat',
#  'giggle',
#  'gossips',
#  'wretches',
#  'confidant',
#  'adviser',
#  'desperately',
#  'red',
#  'incomprehensible',
#  'imagines',
#  'asperity',
#  'blinds',
#  'deserts',
#  'helpmate',
#  'aright',
#  'cry',
#  'statement',
#  'estimated',
#  'richest',
#  'sphere',
#  'legal',
#  'grudged',
#  'distaste',
#  'disinclined',
#  'haphazard',
#  'assertion',
#  'represent',
#  'slightingly',
#  'waiving',
#  'possesses',
#  'misapply',
#  'bewitches',
#  'pick',
#  'puff',
#  'produces',
#  'connecting',
#  'canvassing',
#  '_letting_',
#  'abide',
#  'assistant',
#  'errant',
#  'habitual',
#  'projects',
#  'disclaimed',
#  'unreserved',
#  'apiece',
#  'doings',
#  'promoting',
#  'indistinctness',
#  'adversary',
#  'adequate',
#  'restoratives',
#  'resentfully',
#  'war',
#  'overcoming',
#  'originally',
#  'clayton',
#  'remonstrated',
#  '_particular_',
#  'enviable',
#  'bearer',
#  'endeared',
#  'improving',
#  'chapters',
#  'labouring',
#  'enlarge',
#  'facts',
#  'literary',
#  'transcribing',
#  'quarto',
#  'ornamented',
#  'ciphers',
#  'trophies',
#  'literature',
#  'collections',
#  'requisition',
#  'contribute',
#  'enigmas',
#  'conundrums',
#  'ungallant',
#  'politest',
#  'puzzles',
#  'recited',
#  'doth',
#  'destin',
#  'antidote',
#  'soften',
#  'inspire',
#  'inspiration',
#  'tremor',
#  'loth',
#  'puzzling',
#  'epithets',
#  'justest',
#  'neptune',
#  'trident',
#  'mermaids',
#  'sharks',
#  '----------,',
#  '_court_',
#  '_ship_',
#  'cream',
#  'follows',
#  'completest',
#  'eligibility',
#  'confirm',
#  'embraces',
#  'articulate',
#  "--------.'",
#  'prologue',
#  'motto',
#  'strangest',
#  'smiths',
#  'courts',
#  'pre',
#  'respective',
#  'channel',
#  'edition',
#  'shakespeare',
#  'michaelmas',
#  'texts',
#  'preached',
#  'abbots',
#  'peeped',
#  '_happily_',
#  'comparisons',
#  'rejection',
#  'beaming',
#  'couplet',
#  '_appropriation_',
#  'capacities',
#  'publicity',
#  'affix',
#  'affixed',
#  'souls',
#  'nodded',
#  'stanza',
#  'kindled',
#  'flame',
#  'hood',
#  'wink',
#  'fatal',
#  'garrick',
#  'christened',
#  'catherine',
#  'knife',
#  'knives',
#  'grandpapas',
#  'papas',
#  'hardy',
#  'misbehave',
#  'tosses',
#  'ceiling',
#  'whichever',
#  'push',
#  'conditionally',
#  'rubber',
#  'smilingly',
#  'replacing',
#  'proudest',
#  'sublime',
#  'detached',
#  'angles',
#  'abode',
#  'dwellings',
#  'smartened',
#  'slackened',
#  'curtains',
#  'admires',
#  'intimately',
#  'pools',
#  'pollards',
#  'exteriors',
#  'inducements',
#  'image',
#  'prosing',
#  'undistinguishing',
#  'unfastidious',
#  'unmarried',
#  'celibacy',
#  'contract',
#  'sour',
#  'perforce',
#  'illiberal',
#  'contracted',
#  'sixpence',
#  'occupations',
#  'carpet',
#  'blinder',
#  'stomacher',
#  'knit',
#  'garters',
#  'tires',
#  'distresses',
#  'temptations',
#  'romantic',
#  'vanish',
#  'tottering',
#  'slippery',
#  'sufferers',
#  'empty',
#  'imitation',
#  'lacing',
#  'orders',
#  'pitcher',
#  'broth',
#  'ahead',
#  'theirs',
#  'experienced',
#  'stilton',
#  'cheese',
#  'wiltshire',
#  'cellery',
#  'beet',
#  'root',
#  'pales',
#  'broke',
#  'dexterously',
#  'throwing',
#  'ditch',
#  'inability',
#  'equipped',
#  'ribband',
#  'conducting',
#  'aspect',
#  'schemed',
#  'gallantries',
#  'allusions',
#  'believes',
#  'superintend',
#  'quicken',
#  'henceforth',
#  'prime',
#  'fortuitous',
#  'vacation',
#  'holidays',
#  'nervously',
#  'apprehensively',
#  'forestalling',
#  'maids',
#  'maternal',
#  'tenderly',
#  'ties',
#  'worshipping',
#  'defects',
#  'injuries',
#  'peculiarities',
#  'fidgetiness',
#  'retort',
#  'properest',
#  'unsullied',
#  'grievous',
#  'existed',
#  'flying',
#  'kite',
#  'scarlet',
#  'cobham',
#  'exceeding',
#  'dated',
#  'sept',
#  'finds',
#  'depending',
#  'affords',
#  'sufficiency',
#  'resulted',
#  'restoration',
#  'unceremoniousness',
#  'sauciness',
#  'whim',
#  'discordancies',
#  'lapse',
#  'understandings',
#  '_nearer_',
#  'grievances',
#  '_both_',
#  'burying',
#  'mixing',
#  'magistrate',
#  'anecdote',
#  'attachments',
#  'drain',
#  'fence',
#  'felling',
#  'acre',
#  'wheat',
#  'turnips',
#  'corn',
#  'interrupting',
#  'labours',
#  'basins',
#  'strenuously',
#  'unsafe',
#  'prohibited',
#  'forgets',
#  'attributed',
#  'prevalent',
#  'influenza',
#  'confound',
#  'vicinity',
#  'aches',
#  'palpitations',
#  'middling',
#  'doctoring',
#  'coddling',
#  'graham',
#  'bailiff',
#  'scotland',
#  'praising',
#  'discussed',
#  'comments',
#  'undoubting',
#  'wholesomeness',
#  'philippics',
#  'failures',
#  'cook',
#  'hired',
#  'fixing',
#  'ejaculation',
#  'rumination',
#  'suffice',
#  'relish',
#  'mud',
#  'pure',
#  'lodgings',
#  'coast',
#  'drugs',
#  'sarcastic',
#  'dryness',
#  'interposition',
#  'langham',
#  'maps',
#  'harsh',
#  'attributing',
#  'swiftly',
#  'mornings',
#  'amounted',
#  'especial',
#  '24th',
#  'doom',
#  'feverish',
#  'unavoidable',
#  'absences',
#  'comfortless',
#  'rice',
#  'pudding',
#  'hastening',
#  'inflamed',
#  'throats',
#  'putrid',
#  'excess',
#  'feed',
#  'demand',
#  'conceptions',
#  'impartially',
#  'vision',
#  'rejoicing',
#  'extricated',
#  'employments',
#  'dignities',
#  'balance',
#  'works',
#  'slyness',
#  'regulate',
#  'mistakes',
#  'shrinking',
#  'sky',
#  'milder',
#  'disagreeables',
#  'discontent',
#  'thinner',
#  'clothing',
#  'dismal',
#  'shivering',
#  'colder',
#  'emulate',
#  'administered',
#  'quarrelsome',
#  'wrapped',
#  'dressing',
#  'lengthened',
#  'estimable',
#  'dismay',
#  'sheepskin',
#  'precautions',
#  'contrivances',
#  'fenced',
#  'unpermitted',
#  'snows',
#  'seasonable',
#  'invites',
#  'se',
#  'nnight',
#  'values',
#  'hospitable',
#  'select',
#  'slavery',
#  'disperse',
#  'uninterrupted',
#  'gratifications',
#  'oddities',
#  'enjoyable',
#  'elbow',
#  'obtruding',
#  'solicitously',
#  'internal',
#  'absurd',
#  'overpowering',
#  'syllables',
#  'reviving',
#  '_were_',
#  'coupled',
#  'timed',
#  'released',
#  'saddle',
#  'assented',
#  'secrets',
#  'vagaries',
#  'caprices',
#  'devil',
#  'undergoing',
#  'stands',
#  'instinctive',
#  'braithwaites',
#  '_woman_',
#  'teazed',
#  '_man_',
#  'decides',
#  'exercises',
#  '_when_',
#  'lateness',
#  'convivial',
#  'separations',
#  'augmentation',
#  'improprieties',
#  '_promise_',
#  'implore',
#  'persuasions',
#  'ulcerated',
#  'drifting',
#  'unfeelingly',
#  'blown',
#  'bleak',
#  'midnight',
#  'contrivance',
#  'blocked',
#  'adventurous',
#  'accumulations',
#  'drifted',
#  'shod',
#  'discussing',
#  'whiten',
#  'coachmen',
#  'ring',
#  'rung',
#  'deposited',
#  'lawfully',
#  'demanded',
#  'availing',
#  'declaring',
#  'fearing',
#  'adoring',
#  'unequalled',
#  'unexampled',
#  'professing',
#  'vainly',
#  'drunkenness',
#  'deliver',
#  'boastful',
#  'drunk',
#  'confuse',
#  'inebriety',
#  'struggles',
#  'insinuating',
#  'uppermost',
#  'joyously',
#  'interpret',
#  'respectably',
#  'ends',
#  'misconception',
#  'supplication',
#  'zigzags',
#  'coldly',
#  'proudly',
#  'separating',
#  'curled',
#  'overthrow',
#  'doubled',
#  'unmarked',
#  'dubious',
#  'jumble',
#  'indiscreetly',
#  'insulted',
#  'pretended',
#  'sighs',
#  'devise',
#  'allied',
#  'aggrandise',
#  'heiress',
#  'gradations',
#  'ancient',
#  'landed',
#  'notch',
#  'alliances',
#  'raving',
#  'incongruity',
#  'honesty',
#  'complaisant',
#  'adventuring',
#  'relapse',
#  'dispiriting',
#  'cogitation',
#  'discontinuing',
#  'eclat',
#  'unmirthful',
#  'blundered',
#  'analogy',
#  'unclosed',
#  'retentive',
#  'further',
#  'atmosphere',
#  'unsettled',
#  'frost',
#  'thaw',
#  'unfriendly',
#  'freeze',
#  'prisoner',
#  'confine',
#  'amiableness',
#  'lamentations',
#  'feminine',
#  'retain',
#  'commands',
#  'solemnity',
#  'acknowledgments',
#  'lonely',
#  'promptitude',
#  'undergo',
#  'feeding',
#  'grossly',
#  'prophecies',
#  'blaming',
#  'testifying',
#  'ingenuousness',
#  'lowly',
#  'modesty',
#  'attaching',
#  'abundantly',
#  'console',
#  'resemble',
#  'repressing',
#  'unvarying',
#  'sympathise',
#  'extinction',
#  'routine',
#  'non',
#  'strive',
#  '_unrequited_',
#  'effecting',
#  'cooling',
#  'repellent',
#  'occurs',
#  'proportionate',
#  'depression',
#  'gala',
#  'tempers',
#  'limb',
#  'idlest',
#  'haunts',
#  'proves',
#  'interior',
#  'manoeuvring',
#  'finessing',
#  'vigour',
#  'messages',
#  'shifts',
#  'expedients',
#  'meanly',
#  'hearts',
#  'consistently',
#  'bending',
#  'knack',
#  'transported',
#  'nought',
#  'yielding',
#  'flourishing',
#  'falsehoods',
#  'singular',
#  'french',
#  'aimable',
#  'plausible',
#  '_sensation_',
#  'chattering',
#  'politician',
#  'dispensing',
#  'flatteries',
#  'contributing',
#  'beaufet',
#  'ceremonies',
#  'mistresses',
#  'misses',
#  'usher',
#  'hunting',
#  'hid',
#  'fills',
#  'crosses',
#  'checker',
#  'pore',
#  'deafness',
#  'deafer',
#  'kingdoms',
#  'countries',
#  'dublin',
#  'baly',
#  'craig',
#  '_joint_',
#  'backward',
#  'whirling',
#  'sails',
#  '!)--',
#  'prefers',
#  '_wish_',
#  'wisely',
#  '7th',
#  'hang',
#  'holyhead',
#  'flurry',
#  'regained',
#  'orphan',
#  'lieut',
#  '_______',
#  'regiment',
#  'infantry',
#  'dying',
#  'fondling',
#  'engrafted',
#  'officer',
#  'camp',
#  'educating',
#  'appointments',
#  'subsistence',
#  'lighter',
#  'masters',
#  'nineteen',
#  'instruction',
#  'sobering',
#  'unfelt',
#  'unabated',
#  'defies',
#  'eligibly',
#  'novitiate',
#  'retire',
#  'retained',
#  'relinquished',
#  'compatible',
#  'weakened',
#  'varying',
#  'discharged',
#  'treble',
#  'recovery',
#  'accusation',
#  'refuted',
#  'fuss',
#  'magnified',
#  'depreciating',
#  'fat',
#  'likeliest',
#  'grey',
#  'cavil',
#  'reigning',
#  'twofold',
#  'rendering',
#  'determining',
#  'entitling',
#  'seduced',
#  'actions',
#  'mischievous',
#  'successless',
#  'sucking',
#  'sharer',
#  'purest',
#  'career',
#  'laborious',
#  'recantation',
#  'prejudices',
#  'relapsing',
#  'provocations',
#  'exhibitions',
#  'workbags',
#  'greatness',
#  'cloak',
#  'insight',
#  'suitableness',
#  'delineated',
#  'surmises',
#  'provocation',
#  ...]

# %% [markdown]
# Es posible que de las 20 palabras más frecuentes se pueda inferir algo sobre el texto, por ejemplo, las palabras her y she aparecen cerca de 2500 veces cada una y eso puede sugerir que en el texto se habla de una persona del sexo femenino.
#
# Si se grafica la distribución de frecuencias acumulada, se observa que tan solo esas 20 palabras más frecuentes son casi la mitad del libro (figura 8).

# %%
dist_frec.plot(20, cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
int(len(palabras)/2)
# Out:
# 96213

# %% [markdown]
# En un texto, una colocación es una secuencia de dos o más palabras que ocurren juntas con una frecuencia inusual, por ejemplo, agua dulce, día festivo, juego de mesa u ojo morado. En tal sentido, una colocación es la combinación frecuente de palabras en la que una palabra requiere la presencia de otra para expresar una idea específica.
#
# Una característica de las colocaciones es que son resistentes a la sustitución con palabras que tienen acepciones similares, por ejemplo, ojo negro es rarísimo que se utilice.
#
# El análisis de colocaciones evalúa las coocurrencias y la frecuencia de dos o más palabras en un contexto dado. Para identificar las colocaciones, se requiere extraer de un texto todos los pares de palabras, conocidos como bigramas. NLTK tiene la función **bigrams()** que construye una lista de pares de palabras consecutivas en un texto.

# %%
oracion=['InteligenciaMaestría','en','Artificial','Procesamiento','de','Lenguaje','Natural','Universidad','Tecmilenio']

# %%
list(nltk.bigrams(oracion))
# Out:
# [('InteligenciaMaestría', 'en'),
#  ('en', 'Artificial'),
#  ('Artificial', 'Procesamiento'),
#  ('Procesamiento', 'de'),
#  ('de', 'Lenguaje'),
#  ('Lenguaje', 'Natural'),
#  ('Natural', 'Universidad'),
#  ('Universidad', 'Tecmilenio')]

# %% [markdown]
# Adicionalmente, es posible utilizar distribuciones de frecuencia condicionales para determinar la cantidad de veces que una palabra aparece con otra en el texto. Por ejemplo, en “Emma” de Jean Austen, la palabra “Emma” aparece junto a was o could alrededor de 60 veces, así como had o felt aproximadamente 30 veces.

# %%
palabras = gutenberg.words('austen-emma.txt')
bigramas = nltk.bigrams(palabras)
cfd = nltk.ConditionalFreqDist(bigramas)

# %%
cfd['Emma']
# Out:
# FreqDist({',': 173, "'": 80, 'was': 64, 'could': 61, '.': 44, 'had': 36, ';': 24, 'felt': 19, 'found': 12, 'and': 11, ...})

# %% [markdown]
# Reflexiona:
#
#
#
# *   ¿Cuáles son los corpora y recursos léxicos que serían útiles para analizar la forma de escribir entre autores, los periodos en los que se escribieron ciertos textos o el género del autor que lo escribió?
# *   Te seleccionan para construir un analizador de sentimientos cuyo objetivo es predecir la opinión (negativa o positiva) expresada en un texto. ¿Qué información deberá tener el analizador para etiquetar un texto como positivo o negativo?
#
# *   ¿Cuál sería la entrada del analizador?
# *   ¿Cuál sería su salida?

# %% [markdown]
# <hr/>
# <footer style="text-align:center; font-size:12px; color:gray;">
# © 2026 UNAM Facultado de Ciencias – Todos los derechos reservados
#
# </footer>
